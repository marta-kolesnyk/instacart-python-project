# %% [markdown]
# # 4.10. Final report (task 1-4)
# #

# %% [markdown]
# # List of contents:
# ## 1. Import libraries
# ## 2. Import 'orders_products_customers_merged' dataset
# ## 3. Remove 'first_name' and 'last_name' columns to address PII data
# ## 4. Compare customers behavior across geographic regions
# ## 5. Create an exclusion flag for low-activity customers and exclude them from the data
# ## 6. Export dataframes
# #

# %% [markdown]
# ## 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ## 2. Import 'orders_products_customers_merged' dataset

# %%
# Create path variable
path = r'C:\Users\marta\OneDrive\Documents\2023-09-18 Instacart Basket Analysis'

# %%
# Import dataset
ords_prods_customers = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers_merged.pkl'))

# %%
# Apply function to display all columns wihtin the dataframe
pd.set_option('display.max_columns', None)

# %%
# Check the output
ords_prods_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly busy        Average orders         10
# 1  Regularly busy      Least busy        Average orders         10
# 2  Regularly busy      Least busy           Most orders         10
# 3      Least busy      Least busy        Average orders         10
# 4      Least busy      Least busy           Most orders         10
#
#    loyalty_flag  mean_price spending_flag  median_order_day  \
# 0  New customer    6.367797   Low spender              20.5
# 1  New customer    6.367797   Low spender              20.5
# 2  New customer    6.367797   Low spender              20.5
# 3  New customer    6.367797   Low spender              20.5
# 4  New customer    6.367797   Low spender              20.5
#
#          order_freq_flag first_name last_name  gender    state  age  \
# 0  Non-frequent customer      Linda    Nguyen  Female  Alabama   31
# 1  Non-frequent customer      Linda    Nguyen  Female  Alabama   31
# 2  Non-frequent customer      Linda    Nguyen  Female  Alabama   31
# 3  Non-frequent customer      Linda    Nguyen  Female  Alabama   31
# 4  Non-frequent customer      Linda    Nguyen  Female  Alabama   31
#
#   date_joined  n_dependants fam_status  income
# 0   2/17/2019             3    married   40423
# 1   2/17/2019             3    married   40423
# 2   2/17/2019             3    married   40423
# 3   2/17/2019             3    married   40423
# 4   2/17/2019             3    married   40423

# %%
# Check the dimensions
ords_prods_customers.shape
# Out:
# (32399732, 32)

# %% [markdown]
# ## 3. Remove 'first_name' and 'last_name' columns to address PII data

# %%
# Drop 'first_name' and 'last_name' columns
ords_prods_customers = ords_prods_customers.drop(columns = ['first_name', 'last_name'])

# %%
# Check the result
ords_prods_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly busy        Average orders         10
# 1  Regularly busy      Least busy        Average orders         10
# 2  Regularly busy      Least busy           Most orders         10
# 3      Least busy      Least busy        Average orders         10
# 4      Least busy      Least busy           Most orders         10
#
#    loyalty_flag  mean_price spending_flag  median_order_day  \
# 0  New customer    6.367797   Low spender              20.5
# 1  New customer    6.367797   Low spender              20.5
# 2  New customer    6.367797   Low spender              20.5
# 3  New customer    6.367797   Low spender              20.5
# 4  New customer    6.367797   Low spender              20.5
#
#          order_freq_flag  gender    state  age date_joined  n_dependants  \
# 0  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 1  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 2  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 3  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 4  Non-frequent customer  Female  Alabama   31   2/17/2019             3
#
#   fam_status  income
# 0    married   40423
# 1    married   40423
# 2    married   40423
# 3    married   40423
# 4    married   40423

# %% [markdown]
# ## 4. Compare customers behavior across geographic regions

# %% [markdown]
# ### -- Create 'regions' column

# %%
# Check frequency of values within 'state' column
ords_prods_customers['state'].value_counts(dropna = False)
# Out:
# state
# Pennsylvania            667007
# California              659695
# Rhode Island            656777
# Georgia                 656249
# New Mexico              654400
# Arizona                 653864
# North Carolina          651790
# Oklahoma                651661
# Alaska                  648451
# Minnesota               647738
# Massachusetts           646275
# Wyoming                 644191
# Virginia                641280
# Missouri                640576
# Texas                   640285
# Colorado                639173
# Maine                   638479
# North Dakota            638391
# Alabama                 637863
# Kansas                  637418
# Louisiana               637414
# Delaware                636906
# South Carolina          636677
# Oregon                  636332
# Arkansas                636070
# Nevada                  636034
# New York                635912
# Montana                 635181
# South Dakota            633649
# Illinois                632928
# Hawaii                  632786
# Washington              632722
# Mississippi             632575
# Kentucky                632389
# Michigan                630816
# Florida                 628964
# Ohio                    628218
# Wisconsin               627981
# New Jersey              627599
# Indiana                 627185
# Maryland                626402
# Nebraska                625736
# Iowa                    625429
# Connecticut             622940
# Tennessee               617783
# New Hampshire           615259
# District of Columbia    613598
# West Virginia           612190
# Utah                    611814
# Vermont                 611644
# Idaho                   607036
# Name: count, dtype: int64

# %% [markdown]
# #### All states will be divided by regions according to Wikipedia list: https://simple.wikipedia.org/wiki/List_of_regions_of_the_United_States

# %%
# Create 'regions' list to assign a region for each state
regions = []

for value in ords_prods_customers['state']:
  if value in ['Maine','New Hampshire','Vermont','Massachusetts','Rhode Island','Connecticut','New York','Pennsylvania','New Jersey']:
    regions.append('Northeast')
  elif value in ['Wisconsin','Michigan','Illinois','Indiana','Ohio','North Dakota','South Dakota','Nebraska','Kansas','Minnesota','Iowa','Missouri']:
    regions.append('Midwest')
  elif value in ['Idaho','Montana','Wyoming','Nevada','Utah','Colorado','Arizona','New Mexico']:
    regions.append('West')
  else:
    regions.append('South')

# %%
# Create 'regions' column within dataframe
ords_prods_customers['regions'] = regions

# %%
# Check the output
ords_prods_customers.head()
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0  Regularly busy  Regularly busy        Average orders         10
# 1  Regularly busy      Least busy        Average orders         10
# 2  Regularly busy      Least busy           Most orders         10
# 3      Least busy      Least busy        Average orders         10
# 4      Least busy      Least busy           Most orders         10
#
#    loyalty_flag  mean_price spending_flag  median_order_day  \
# 0  New customer    6.367797   Low spender              20.5
# 1  New customer    6.367797   Low spender              20.5
# 2  New customer    6.367797   Low spender              20.5
# 3  New customer    6.367797   Low spender              20.5
# 4  New customer    6.367797   Low spender              20.5
#
#          order_freq_flag  gender    state  age date_joined  n_dependants  \
# 0  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 1  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 2  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 3  Non-frequent customer  Female  Alabama   31   2/17/2019             3
# 4  Non-frequent customer  Female  Alabama   31   2/17/2019             3
#
#   fam_status  income regions
# 0    married   40423   South
# 1    married   40423   South
# 2    married   40423   South
# 3    married   40423   South
# 4    married   40423   South

# %%
# Check frequency of values within 'regions' column
ords_prods_customers['regions'].value_counts()
# Out:
# regions
# South        14000082
# Midwest       7596065
# Northeast     5721892
# West          5081693
# Name: count, dtype: int64

# %% [markdown]
# ### -- Compare customer spendings across regions

# %%
# Create crosstab between 'regions' and 'spending_flag' columns
crosstab_reg_spend = pd.crosstab(ords_prods_customers['regions'], ords_prods_customers['spending_flag'], dropna = False)

# %%
# Check the output
crosstab_reg_spend
# Out:
# spending_flag  High spender  Low spender
# regions
# Midwest               29265      7566800
# Northeast             18639      5703253
# South                 52506     13947576
# West                  19309      5062384

# %% [markdown]
# #### All regions share the same tendency of having more low spenders than high spenders. South region has the highest number of high- and low-spending customers, each group has 43% of total.
# #### Northeast and West regions have approximately 16% of high spenders each. West has the lowest percentage of low spenders, which is 15,6%.

# %% [markdown]
# ## 5. Create an exclusion flag for low-activity customers and exclude them from the data

# %% [markdown]
# ### -- Create exclusion 'user_activity_flag'

# %%
 # Set first condition (low-activity customers if orders number <5)0
ords_prods_customers.loc[ords_prods_customers['max_order'] < 5, 'user_activity_flag'] = 'Low activity'

# %%
 # Set second condition (regular customers if orders number >=5)
ords_prods_customers.loc[ords_prods_customers['max_order'] >= 5, 'user_activity_flag'] = 'Normal activity'

# %%
# Check the output
ords_prods_customers['user_activity_flag'].value_counts(dropna = False)
# Out:
# user_activity_flag
# Normal activity    30959687
# Low activity        1440045
# Name: count, dtype: int64

# %%
# Check the output
ords_prods_customers
# Out:
#           order_id user_id  order_number  order_day_of_week  \
# 0          2539329       1             1                  2
# 1          2398795       1             2                  3
# 2           473747       1             3                  3
# 3          2254736       1             4                  4
# 4           431534       1             5                  4
# ...            ...     ...           ...                ...
# 32399727    156685  106143            26                  4
# 32399728    484769   66343             1                  6
# 32399729   1561557   66343             2                  1
# 32399730    276317   66343             3                  6
# 32399731   2922475   66343             4                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# 2                        12                    21.0         196
# 3                         7                    29.0         196
# 4                        15                    28.0         196
# ...                     ...                     ...         ...
# 32399727                 23                     5.0       19675
# 32399728                 11                     NaN       47210
# 32399729                 11                    30.0       47210
# 32399730                 15                    19.0       47210
# 32399731                 12                    30.0       47210
#
#           add_to_cart_order  reordered                 product_name  aisle_id  \
# 0                         1          0                         Soda        77
# 1                         1          1                         Soda        77
# 2                         1          1                         Soda        77
# 3                         1          1                         Soda        77
# 4                         1          1                         Soda        77
# ...                     ...        ...                          ...       ...
# 32399727                  1          1  Organic Raspberry Black Tea        94
# 32399728                  1          0  Fresh Farmed Tilapia Fillet        15
# 32399729                  1          1  Fresh Farmed Tilapia Fillet        15
# 32399730                  1          1  Fresh Farmed Tilapia Fillet        15
# 32399731                  1          1  Fresh Farmed Tilapia Fillet        15
#
#           department_id  prices    price_range_loc     busiest_day  \
# 0                     7     9.0  Mid-range product  Regularly busy
# 1                     7     9.0  Mid-range product  Regularly busy
# 2                     7     9.0  Mid-range product  Regularly busy
# 3                     7     9.0  Mid-range product      Least busy
# 4                     7     9.0  Mid-range product      Least busy
# ...                 ...     ...                ...             ...
# 32399727              7    10.7  Mid-range product      Least busy
# 32399728             12     8.1  Mid-range product  Regularly busy
# 32399729             12     8.1  Mid-range product  Regularly busy
# 32399730             12     8.1  Mid-range product  Regularly busy
# 32399731             12     8.1  Mid-range product  Regularly busy
#
#             busiest_days busiest_period_of_day  max_order      loyalty_flag  \
# 0         Regularly busy        Average orders         10      New customer
# 1             Least busy        Average orders         10      New customer
# 2             Least busy           Most orders         10      New customer
# 3             Least busy        Average orders         10      New customer
# 4             Least busy           Most orders         10      New customer
# ...                  ...                   ...        ...               ...
# 32399727      Least busy         Fewest orders         26  Regular customer
# 32399728  Regularly busy           Most orders          4      New customer
# 32399729     Busiest day           Most orders          4      New customer
# 32399730  Regularly busy           Most orders          4      New customer
# 32399731     Busiest day           Most orders          4      New customer
#
#           mean_price spending_flag  median_order_day        order_freq_flag  \
# 0           6.367797   Low spender              20.5  Non-frequent customer
# 1           6.367797   Low spender              20.5  Non-frequent customer
# 2           6.367797   Low spender              20.5  Non-frequent customer
# 3           6.367797   Low spender              20.5  Non-frequent customer
# 4           6.367797   Low spender              20.5  Non-frequent customer
# ...              ...           ...               ...                    ...
# 32399727   10.700000  High spender               7.0      Frequent customer
# 32399728    8.100000   Low spender              30.0  Non-frequent customer
# 32399729    8.100000   Low spender              30.0  Non-frequent customer
# 32399730    8.100000   Low spender              30.0  Non-frequent customer
# 32399731    8.100000   Low spender              30.0  Non-frequent customer
#
#           gender      state  age date_joined  n_dependants fam_status  income  \
# 0         Female    Alabama   31   2/17/2019             3    married   40423
# 1         Female    Alabama   31   2/17/2019             3    married   40423
# 2         Female    Alabama   31   2/17/2019             3    married   40423
# 3         Female    Alabama   31   2/17/2019             3    married   40423
# 4         Female    Alabama   31   2/17/2019             3    married   40423
# ...          ...        ...  ...         ...           ...        ...     ...
# 32399727    Male     Hawaii   25   5/26/2017             0     single   53755
# 32399728  Female  Tennessee   22   9/12/2017             3    married   46151
# 32399729  Female  Tennessee   22   9/12/2017             3    married   46151
# 32399730  Female  Tennessee   22   9/12/2017             3    married   46151
# 32399731  Female  Tennessee   22   9/12/2017             3    married   46151
#
#          regions user_activity_flag
# 0          South    Normal activity
# 1          South    Normal activity
# 2          South    Normal activity
# 3          South    Normal activity
# 4          South    Normal activity
# ...          ...                ...
# 32399727   South    Normal activity
# 32399728   South       Low activity
# 32399729   South       Low activity
# 32399730   South       Low activity
# 32399731   South       Low activity
#
# [32399732 rows x 32 columns]

# %% [markdown]
# ### -- Remove low-activity customers from dataframe

# %%
# Create subset df with only low-activity customers
df_low_activity = ords_prods_customers[ords_prods_customers['user_activity_flag'] == 'Low activity']

# %%
# Check the output
df_low_activity['user_activity_flag'].value_counts()
# Out:
# user_activity_flag
# Low activity    1440045
# Name: count, dtype: int64

# %%
# Create subset df with only normal-activity customers
df_normal_activity = ords_prods_customers[ords_prods_customers['user_activity_flag'] == 'Normal activity']

# %%
# Check the output
df_normal_activity['user_activity_flag'].value_counts()
# Out:
# user_activity_flag
# Normal activity    30959687
# Name: count, dtype: int64

# %%
# Check the total length of new dataframes
len(df_normal_activity) + len(df_low_activity)
# Out:
# 32399732

# %% [markdown]
# ## 6. Export dataframes

# %%
# Export ords_prods_customers dataframe in pkl format
ords_prods_customers.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers_final.pkl'))

# %%
# Export df_normal_activity dataframe in pkl format
df_normal_activity.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'subset_customers_norm_activity.pkl'))

# %%
# Export df_normal_activity dataframe in pkl format
df_low_activity.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'subset_customers_low_activity.pkl'))
